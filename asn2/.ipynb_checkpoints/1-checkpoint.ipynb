# %%
import numpy as np
from numpy import linalg as LA
from numpy import array, dot, mean, std, empty, argsort
from numpy.linalg import eigh, solve
from matplotlib.pyplot import subplots, show

# %%
def pca(data, pc_count = None):
    """
    Principal component analysis using eigenvalues
    note: this mean-centers and auto-scales the data (in-place)
    """
    data -= mean(data, 0)
#     data /= std(data, 0)
    C = np.cov(data)
    E, V = eigh(C)
    print E.shape
    print V.shape
    key = argsort(E)[::-1][:pc_count]
    E, V = E[key], V[:, key]
    print E.shape, V.shape, data.shape
    U = dot(V.T, data).T 
    return U, E, V

# %%
df = "iris.csv"
data = np.loadtxt(df, delimiter=',',usecols=(0,1,2,3))


trans = pca(data, 2)[0]
plt.figure()
plt.title('PCA for IRIS dataset')
plt.scatter(trans[:50, 0], trans[:50, 1], c = 'r')
plt.scatter(trans[50:100, 0], trans[50:100, 1], c = 'b')
plt.scatter(trans[100:, 0], trans[100:, 1], c = 'g')
show()
# Out:
# (150,)
# (150, 150)
# (2,) (150, 2) (150, 4)

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
X_tsne = TSNE(learning_rate=100,random_state=400).fit_transform(data)

plt.figure()
plt.title('TSNE for IRIS dataset')
plt.scatter(X_tsne[:50, 0], X_tsne[:50, 1], c='r')
plt.scatter(X_tsne[50:100, 0], X_tsne[50:100, 1], c='b')
plt.scatter(X_tsne[100:, 0], X_tsne[100:, 1], c='g')

plt.show()

# %%
from sklearn.datasets import make_swiss_roll 
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

data, color = make_swiss_roll(n_samples=1500,noise=0.0,random_state=None)

X_tsne = TSNE(learning_rate=100).fit_transform(data)
X_pca = pca(data)[0]

# %%
plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=color)
plt.title('TSNE for SwissRoll dataset')
plt.subplot(122)
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=color)
plt.title('PCA for SwissRoll dataset')


plt.show()
